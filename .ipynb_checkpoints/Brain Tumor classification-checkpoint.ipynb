# %% [markdown]
# # Brain Tumor Classification Using CNN 🧠

# %%
import os
import keras 
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # Data Preprocessing

# %%
# one hot encoding the target

# %%
encoder = OneHotEncoder()
encoder.fit([[0], [1]])

# 0- no tumor(Normal) 

# 1- Tumor
# Out:
# OneHotEncoder()

# %%
# image preprocessing for tumor images

data = []
paths = []
result = []
# change the directory to your own
for r, d, f in os.walk("/Users/mesaye/Documents/GitHub/brain-tumor-detection/yes"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[1]]).toarray())

# %%
# image preprocessing for no tumor images

paths = []

for r, d, f in os.walk("/Users/mesaye/Documents/GitHub/brain-tumor-detection/no"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[0]]).toarray())

# %%
data = np.array(data)
data.shape
# Out:
# (139, 128, 128, 3)

# %%
result = np.array(result)
result = result.reshape(139,2)

# %%
#data

# %%
# split into train and test set
x_train,x_test,y_train,y_test = train_test_split(data, result, test_size=0.2, shuffle=True, random_state=0)

# %%
# data normalization

x_valid, x_train = x_train[:25] / 255 , x_train[25:] / 255
y_valid, y_train = y_train[:25], y_train[25:]
x_test = x_test / 255.

# %%
print(x_valid.shape)
print(y_valid.shape)
print(y_train.shape)
print(x_test.shape)
print(x_train.shape)
# Out:
# (25, 128, 128, 3)
# (25, 2)
# (86, 2)
# (28, 128, 128, 3)
# (86, 128, 128, 3)

# %% [markdown]
# # Build the CNN Neural Network

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(2, 2), input_shape=(128, 128, 3), padding = 'Same'))
model.add(Conv2D(32, kernel_size=(2, 2),  activation ='relu', padding = 'Same'))


model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))

model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))
# Out:
# 2022-04-12 13:46:33.447379: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(loss = "categorical_crossentropy", optimizer='Adam',metrics=["accuracy"])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 128, 128, 32)      416
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      4128
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 64)        8256
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 64)        16448
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 512)               33554944
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# ...
# Total params: 33,585,218
# Trainable params: 33,585,218
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# fit the model

history = model.fit(x_train, y_train, epochs = 10, verbose = 1,validation_data = (x_valid, y_valid))
# Out:
# Epoch 1/10
# 3/3 [==============================] - 2s 534ms/step - loss: 2.2446 - accuracy: 0.4884 - val_loss: 1.9286 - val_accuracy: 0.6000
# Epoch 2/10
# 3/3 [==============================] - 1s 465ms/step - loss: 1.2580 - accuracy: 0.5698 - val_loss: 0.9364 - val_accuracy: 0.4400
# Epoch 3/10
# 3/3 [==============================] - 1s 458ms/step - loss: 0.5606 - accuracy: 0.7442 - val_loss: 0.6621 - val_accuracy: 0.6000
# Epoch 4/10
# 3/3 [==============================] - 1s 471ms/step - loss: 0.4946 - accuracy: 0.7674 - val_loss: 0.7301 - val_accuracy: 0.5600
# Epoch 5/10
# 3/3 [==============================] - 2s 508ms/step - loss: 0.4711 - accuracy: 0.7209 - val_loss: 0.7078 - val_accuracy: 0.6000
# Epoch 6/10
# 3/3 [==============================] - 2s 526ms/step - loss: 0.4003 - accuracy: 0.7907 - val_loss: 0.6574 - val_accuracy: 0.5600
# Epoch 7/10
# ...

# %%
score = model.evaluate(x_test, y_test)
# Out:
# 1/1 [==============================] - 0s 121ms/step - loss: 0.7906 - accuracy: 0.6071

# %%
pd.DataFrame(history.history).plot(figsize=(8, 6))
plt.grid(True)
plt.gca().set_ylim(0, 2)
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Test', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# # Prediction

# %%
def names(number):
    if number==0:
        return 'No Tumor detected'
    else:
        return 'Tumor detected'

# %%
from matplotlib.pyplot import imshow
img = Image.open("/Users/mesaye/Documents/GitHub/brain-tumor-detection/yes/Y159.JPG")# test image 

x = np.array(img.resize((128,128)))

x = x.reshape(1,128,128,3)

# %%
res = model.predict(x)

classification = np.where(res == np.amax(res))[1][0]

imshow(img)
print(str(res[0][classification]*100) + '% Confidence' + names(classification))
# Out:
# 100.0% ConfidenceTumor detected
